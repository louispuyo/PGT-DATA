# %%
url='http://nbviewer.ipython.org/github/jmportilla/Udemy-notes/blob/master/Intro%20to%20Data%20Project%20Section.ipynb'

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
data = pd.read_csv('Work/NLTP/data/pgt-depenses-2016.csv', header=None)

# %%
df = pd.DataFrame(data, columns=list('ABCDEFGH'))
df

# %%
df = df.rename(columns={'A':'Date', 'B':'Fournisseur'})
df

# %%
df = pd.pivot(df, columns={'A':'Date', 'B':'Fournisseur'})
df

# %%
data

# %%
data

# %%
data
# Out:
#                                               0  \
# 0    S-DPC| 0566| S01| 1034| 20160101| 20161231
# 1                               CABINET PAGESTI
# 2                                           NaN
# 3                                           NaN
# 4                                          Date
# ..                                          ...
# 365                                  09/12/2016
# 366                                         NaN
# 367                                         NaN
# 368                                         NaN
# 369                 Edité le 12/06/2017 à 09:34
#
#                                                  1  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# ...

# %%
data.head(20)
# Out:
#                                              0  \
# 0   S-DPC| 0566| S01| 1034| 20160101| 20161231
# 1                              CABINET PAGESTI
# 2                                          NaN
# 3                                          NaN
# 4                                         Date
# 5                                          NaN
# 6                                          NaN
# 7                                   08/02/2016
# 8                                          NaN
# 9                                   09/05/2016
# 10                                         NaN
# 11                                  08/08/2016
# 12                                         NaN
# 13                                  07/11/2016
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                  26/01/2016
# 18                                         NaN
# ...

# %%
df1 = data[1]

# %%
df1.head(20)
df1 = df1.dropna()
df1.head(50)
# Out:
# 6                                      EAU FROIDE
# 7                       Facture du 08/02/16 695m3
# 8                               Four: EAU & FORCE
# 9                       Facture du 09/05/16 688m3
# 10                             Four: EAU DE PARIS
# 11                      Facture du 08/08/16 669m3
# 12                             Four: EAU DE PARIS
# 13                      Facture du 07/11/16 660m3
# 14                             Four: EAU DE PARIS
# 15               Total compte 60100000 EAU FROIDE
# 16                          EDF SERVICES GENERAUX
# 17                            Facture du 26/01/16
# 18                        Four: E.D.F Entreprises
# 19                            Facture du 23/03/16
# 20                        Four: E.D.F Entreprises
# 21                            Facture du 23/03/16
# 22                        Four: E.D.F Entreprises
# 23                            Facture du 25/05/16
# 24                        Four: E.D.F Entreprises
# ...

# %%
import pandas as pd

# %%
import dask.dataframe as dd

df = dd.read_csv("/home/snowden/Work/WebApp-Flask/pgt-depenses-2016.csv")
df.head()
# Out:
#   S-DPC| 0566| S01| 1034| 20160101| 20161231 Unnamed: 1  \
# 0                            CABINET PAGESTI        NaN
# 1                                        NaN        NaN
# 2                                        NaN        NaN
# 3                                       Date        NaN
# 4                                        NaN        NaN
#
#                                           Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0                                Copropriété N° 1034        NaN          NaN
# 1           34 RUE DU FBG SAINT-MARTIN - 75010 PARIS        NaN          NaN
# 2  Détail des DEPENSES de la période du 01/01/201...        NaN          NaN
# 3                                           Libellés   Montants  Récupérable
# 4                             0001 CHARGES GENERALES        NaN          NaN
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0   Page N° 1        NaN        NaN
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# ...

# %%
df['Unnamed: 1'].compute().head(50)
# Out:
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                      EAU FROIDE
# 6                       Facture du 08/02/16 695m3
# 7                               Four: EAU & FORCE
# 8                       Facture du 09/05/16 688m3
# 9                              Four: EAU DE PARIS
# 10                      Facture du 08/08/16 669m3
# 11                             Four: EAU DE PARIS
# 12                      Facture du 07/11/16 660m3
# 13                             Four: EAU DE PARIS
# 14               Total compte 60100000 EAU FROIDE
# 15                          EDF SERVICES GENERAUX
# 16                            Facture du 26/01/16
# 17                        Four: E.D.F Entreprises
# 18                            Facture du 23/03/16
# ...

# %%
import dask.dataframe as dd
import pandas as pd

df = dd.read_csv("/home/snowden/Work/WebApp-Flask/pgt-depenses-2016.csv")

df.head()
orgDF = df["Unnamed: 1"]

iter_csv = pd.read_csv("/home/snowden/Work/WebApp-Flask/pgt-depenses-2016.csv",
                       iterator=True,
                       chunksize=1000)

df = pd.concat([chunk[chunk["Unnamed: 1"].str.contains("Four:", na=False)]
                for chunk in iter_csv])
df
# Out:
#     S-DPC| 0566| S01| 1034| 20160101| 20161231                    Unnamed: 1  \
# 7                                          NaN             Four: EAU & FORCE
# 9                                          NaN            Four: EAU DE PARIS
# 11                                         NaN            Four: EAU DE PARIS
# 13                                         NaN            Four: EAU DE PARIS
# 17                                         NaN       Four: E.D.F Entreprises
# ..                                         ...                           ...
# 350                                        NaN        Four:S.A.R.L. T.P.V.S.
# 352                                        NaN        Four:S.A.R.L. T.P.V.S.
# 356                                        NaN            Four:Société SICLI
# 358                                        NaN            Four:Société SICLI
# 363                                        NaN  Four:S.A.R.L. AMJ Rénovation
#
# ...

# %%
df2.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4aff20dda6be> in <module>
# ----> 1 df2.head(50)
#
# NameError: name 'df2' is not defined

# %%
df2.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4aff20dda6be> in <module>
# ----> 1 df2.head(50)
#
# NameError: name 'df2' is not defined

# %%
df2 = pd.concat([chunk[chunk["Unnamed: 1"].str.startswith(prefix[, start[, end]])]
                 for chunk in iter_csv])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c55f364ec053> in <module>
#       1 df2 = pd.concat([chunk[chunk["Unnamed: 1"].str.contains("Total", na=False)]
# ----> 2                  for chunk in iter_csv])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     302
#     303         if len(objs) == 0:
# --> 304             raise ValueError("No objects to concatenate")
#     305
#     306         if keys is None:
# ...

# %%
df
# Out:
#     S-DPC| 0566| S01| 1034| 20160101| 20161231                    Unnamed: 1  \
# 7                                          NaN             Four: EAU & FORCE
# 9                                          NaN            Four: EAU DE PARIS
# 11                                         NaN            Four: EAU DE PARIS
# 13                                         NaN            Four: EAU DE PARIS
# 17                                         NaN       Four: E.D.F Entreprises
# ..                                         ...                           ...
# 350                                        NaN        Four:S.A.R.L. T.P.V.S.
# 352                                        NaN        Four:S.A.R.L. T.P.V.S.
# 356                                        NaN            Four:Société SICLI
# 358                                        NaN            Four:Société SICLI
# 363                                        NaN  Four:S.A.R.L. AMJ Rénovation
#
# ...
